# %%
#Data manipulation
import pandas as pd

# Plotting
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df = pd.read_excel('Source/Bankless DAO Volunteers (Responses).xlsx', index_col=0)

# Drop rows with no information
df.dropna(how='all', inplace=True)

# %%
df.head()
# Out:
#                                  Discord Handle  \
# Timestamp
# 2021-05-08 13:11:05.360  Above Average Joe#5427
# 2021-05-08 13:11:32.627          Jcrypto69#3561
# 2021-05-08 13:12:12.890     deepspacechase#4300
# 2021-05-08 13:12:30.527          johnnypgh#8268
# 2021-05-08 13:13:25.179    letsbecomehuman#4994
#
#                         What role(s) are you volunteering for?  \
# Timestamp
# 2021-05-08 13:11:05.360                      Community Manager
# 2021-05-08 13:11:32.627                      Community Manager
# 2021-05-08 13:12:12.890                      Community Manager
# 2021-05-08 13:12:30.527      Community Manager, UI/UX Designer
# 2021-05-08 13:13:25.179                      Community Manager
#
#                         What experience do you have with the roles you're volunteering for?
# Timestamp
# 2021-05-08 13:11:05.360                                                NaN
# 2021-05-08 13:11:32.627                                                NaN
# ...

# %%
df.loc[df['What role(s) are you volunteering for?'] == 'Community Manager', 'role'] = '1'  
df.loc[df['What role(s) are you volunteering for?'] == 'Analytics', 'role'] = '2'
df.loc[df['What role(s) are you volunteering for?'] == 'Backend Dev', 'role'] = '3'
df.loc[df['What role(s) are you volunteering for?'] == 'Creative (e.g., graphic design or NFT creation)', 'role'] = '4'  
df.loc[df['What role(s) are you volunteering for?'] == 'Ethereum Devs', 'role'] = '5'
df.loc[df['What role(s) are you volunteering for?'] == 'Frontend Dev', 'role'] = '6'
df.loc[df['What role(s) are you volunteering for?'] == 'Government and Regulatory Affairs', 'role'] = '7'
df.loc[df['What role(s) are you volunteering for?'] == 'Creative (Product Management', 'role'] = '8'  
df.loc[df['What role(s) are you volunteering for?'] == 'Research Analyst', 'role'] = '9'
df.loc[df['What role(s) are you volunteering for?'] == 'Translator - Chinese', 'role'] = '10'
df.loc[df['What role(s) are you volunteering for?'] == 'Translator - Korean', 'role'] = '11'
df.loc[df['What role(s) are you volunteering for?'] == 'Translator - Portuguese', 'role'] = '12'  
df.loc[df['What role(s) are you volunteering for?'] == 'Translator - Spanish', 'role'] = '13'
df.loc[df['What role(s) are you volunteering for?'] == 'Translator - Vietnamese', 'role'] = '14'
df.loc[df['What role(s) are you volunteering for?'] == 'Twitter Meme Lord', 'role'] = '15'  
df.loc[df['What role(s) are you volunteering for?'] == 'UI/UX Designer', 'role'] = '16'
df.loc[df['What role(s) are you volunteering for?'] == 'Writer', 'role'] = '17'
df.loc[df['What role(s) are you volunteering for?'] == 'Other', 'role'] = '18' 
    
    
print (df)
# Out:
#                                  Discord Handle  \
# Timestamp
# 2021-05-08 13:11:05.360  Above Average Joe#5427
# 2021-05-08 13:11:32.627          Jcrypto69#3561
# 2021-05-08 13:12:12.890     deepspacechase#4300
# 2021-05-08 13:12:30.527          johnnypgh#8268
# 2021-05-08 13:13:25.179    letsbecomehuman#4994
# 2021-05-08 13:14:07.983        LostBoy.eth#9517
# 2021-05-08 13:14:36.761         DarkKnight#2268
# 2021-05-08 13:15:02.209     Ronin Imperial#6299
# 2021-05-08 13:15:32.251           Oenochoe#8730
# 2021-05-08 13:17:39.329            blitzio#7777
# 2021-05-08 13:17:55.389            bfgallo#9104
# 2021-05-08 13:18:36.223            Bordini#3125
# 2021-05-08 13:18:51.685         Daniel Jee#5005
# 2021-05-08 13:19:10.393              Jacks#6609
# 2021-05-08 13:19:27.144             Scrohe#6939
# 2021-05-08 13:19:36.350          Ethereyum#9881
# 2021-05-08 13:19:46.098               MW 🏴#4059
# 2021-05-08 13:20:01.196           nikkoque#0912
# ...

# %%
df.head()
# Out:
#                                  Discord Handle  \
# Timestamp
# 2021-05-08 13:11:05.360  Above Average Joe#5427
# 2021-05-08 13:11:32.627          Jcrypto69#3561
# 2021-05-08 13:12:12.890     deepspacechase#4300
# 2021-05-08 13:12:30.527          johnnypgh#8268
# 2021-05-08 13:13:25.179    letsbecomehuman#4994
#
#                         What role(s) are you volunteering for?  \
# Timestamp
# 2021-05-08 13:11:05.360                      Community Manager
# 2021-05-08 13:11:32.627                      Community Manager
# 2021-05-08 13:12:12.890                      Community Manager
# 2021-05-08 13:12:30.527      Community Manager, UI/UX Designer
# 2021-05-08 13:13:25.179                      Community Manager
#
#                         What experience do you have with the roles you're volunteering for?  \
# Timestamp
# 2021-05-08 13:11:05.360                                                NaN
# 2021-05-08 13:11:32.627                                                NaN
# ...

# %%
df.to_csv('BANKLESS DAO VOLUNTEER List.csv',index=False)
